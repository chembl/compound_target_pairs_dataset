# %% [markdown]
# # Query ChEMBL info for the prodrugs in the supplementary material

# %%
import pandas as pd
import sqlite3

# %%
chembl_version = "26"
base_path = "/Users/heinzke/Documents/PhD/Projects/drug_target_dataset_curation/"
path_results = base_path+"results/"
path_sqlite3_database = base_path+"data/chembl_"+chembl_version+"/chembl_"+chembl_version+"_sqlite/chembl_"+chembl_version+".db"

paper_path = base_path + 'data/jm1c00416_si_002.xlsx'
engine_ch = sqlite3.connect(path_sqlite3_database)

# %% [markdown]
# ## List of prodrugs and active metabolites from the supplementary material

# %%
df_paper = pd.read_excel(open(paper_path, 'rb'), sheet_name='Manual curation_prodrugs')
df_paper
# Out:
#      CMPD_PREF_NAME (Active metabolite)  \
# 0   2',3'-DIDEOXYADENOSINE TRIPHOSPHATE
# 1        7-ETHYL-10-HYDROXYCAMPTOTHECIN
# 2                           ABIRATERONE
# 3                           AFIMOXIFENE
# 4                           CANDESARTAN
# 5                        CLOFIBRIC ACID
# 6                            DABIGATRAN
# 7                       DESGLYMIDODRINE
# 8                         DESLORATADINE
# 9                           ENALAPRILAT
# 10                    ETHINYL ESTRADIOL
# 11                      FENOFIBRIC ACID
# 12                         FEXOFENADINE
# 13        FINGOLIMOD PHOSPHATE/FTY720-P
# 14                         FLUPROSTENOL
# 15                         FOSINOPRILAT
# 16                          HALOPERIDOL
# 17                     HYDROXYFLUTAMIDE
# 18              LAMIVUDINE TRIPHOSPHATE
# 19                          LANINAMIVIR
# 20             LOXOPROFEN TRANS ALCOHOL
# 21          OSELTAMIVIR CARBOXYLIC ACID
# 22                           OXYPURINOL
# 23                         PREDNISOLONE
# 24                          QUINAPRILAT
# 25                                R-406
# 26                  ROMIDESPSIN_DITHIOL
# 27                          SPIRAPRILAT
# 28               STAVUDINE TRIPHOSPHATE
# 29                     SULINDAC SULFIDE
# 30                         TESTOSTERONE
# 31              ZIDOVUDINE TRIPHOSPHATE
# 32                        BETAMETHASONE
# 33                        TERIFLUNOMIDE
# 34                          IMIDAPRILAT
# 35                            ESTRADIOL
# 36                          CYCLOGUANIL
# 37                           MELAGATRAN
#
#    CMPD_PREF_NAME (Prodrug removed,  potency data for active metabolite-drug target interaction used in analysis)  \
# 0                                          Didanosine
# 1                                          Irinotecan
# 2                                 Abiraterone acetate
# 3                                           Tamoxifen
# 4                               Candesartan cilexetil
# 5                                          Clofibrate
# 6                                Dabigatran etexilate
# 7                                           Midodrine
# 8                                          Loratidine
# 9                                           Enalapril
# 10                                          Mestranol
# 11                                        Fenofibrate
# 12                                        Terfenadine
# 13                                         Fingolimod
# 14                                         Travoprost
# 15                                         Fosinopril
# 16                              Haloperidol decanoate
# 17                                          Flutamide
# 18                                         Lamivudine
# 19                              Laninamivir octanoate
# 20                                         Loxoprofen
# 21                                        Oseltamivir
# 22                                        Allopurinol
# 23                                         Prednisone
# 24                                          Quinapril
# 25                                       Fostamatinib
# 26                                         Romidepsin
# 27                                          Spirapril
# 28                                          Stavudine
# 29                                           Sulindac
# 30                            Testosterone propionate
# 31                                         Zidovudine
# 32                      Betamethasone phosphoric acid
# 33                                        Leflunomide
# 34                                          Imidapril
# 35                                 Estradiol benzoate
# 36                                      Chloroguanide
# 37                                       Ximelagatran
#
#     Unnamed: 2  Unnamed: 3 CMPD_PREF_NAME (Active metabolite).1  \
# 0          NaN         NaN                CARBOVIR TRIPHOSPHATE
# 1          NaN         NaN  5-AZA-2′-DEOXYCYTIDINE TRIPHOSPHATE
# 2          NaN         NaN              DECITABINE TRIPHOSPHATE
# 3          NaN         NaN                          DIFLORASONE
# 4          NaN         NaN                          MOEXIPRILAT
# 5          NaN         NaN                        PERINDOPRILAT
# 6          NaN         NaN                           RAMIPRILAT
# 7          NaN         NaN                     TAZAROTENIC ACID
# 8          NaN         NaN                       TRANDOLAPRILAT
# 9          NaN         NaN                         BENAZEPRILAT
# 10         NaN         NaN                     MEVINOLINIC ACID
# 11         NaN         NaN                         TENIVASTATIN
# 12         NaN         NaN                            GS-461203
# 13         NaN         NaN                                DDCTP
# 14         NaN         NaN             OMEPRAZOLE SULFENIC ACID
# 15         NaN         NaN                           ROXATIDINE
# 16         NaN         NaN                          CAREBASTINE
# 17         NaN         NaN                    4-OH-ENCLOMIPHENE
# 18         NaN         NaN                                  NaN
# 19         NaN         NaN                                  NaN
# 20         NaN         NaN                                  NaN
# 21         NaN         NaN                                  NaN
# 22         NaN         NaN                                  NaN
# 23         NaN         NaN                                  NaN
# 24         NaN         NaN                                  NaN
# 25         NaN         NaN                                  NaN
# 26         NaN         NaN                                  NaN
# 27         NaN         NaN                                  NaN
# 28         NaN         NaN                                  NaN
# 29         NaN         NaN                                  NaN
# 30         NaN         NaN                                  NaN
# 31         NaN         NaN                                  NaN
# 32         NaN         NaN                                  NaN
# 33         NaN         NaN                                  NaN
# 34         NaN         NaN                                  NaN
# 35         NaN         NaN                                  NaN
# 36         NaN         NaN                                  NaN
# 37         NaN         NaN                                  NaN
#
#    CMPD_PREF_NAME (Prodrug removed, not used in analysis since no potency data for active metabolite-drug target interaction)
# 0                                            Abacavir
# 1                                         Azacitidine
# 2                                          Decitabine
# 3                               Diflorasone diacetate
# 4                                           Moexipril
# 5                                         Perindopril
# 6                                            Ramipril
# 7                                          Tazarotene
# 8                                        Trandolapril
# 9                                          Benazepril
# 10                                         Lovastatin
# 11                                        Simvastatin
# 12                                         Sofosbuvir
# 13                                        Zalcitabine
# 14                                         Omeprazole
# 15                                 Roxatidine acetate
# 16                                           Ebastine
# 17                                       Enclomiphene
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN

# %%
prodrugs_1 = df_paper[['CMPD_PREF_NAME (Active metabolite)', 'CMPD_PREF_NAME (Prodrug removed,  potency data for active metabolite-drug target interaction used in analysis)']]
prodrugs_1 = prodrugs_1.rename(columns={'CMPD_PREF_NAME (Active metabolite)':'active_metabolite_pref_name',
                          'CMPD_PREF_NAME (Prodrug removed,  potency data for active metabolite-drug target interaction used in analysis)':'prodrug_pref_name'})
prodrugs_1['column'] = 1
prodrugs_1
# Out:
#             active_metabolite_pref_name              prodrug_pref_name  column
# 0   2',3'-DIDEOXYADENOSINE TRIPHOSPHATE                     Didanosine       1
# 1        7-ETHYL-10-HYDROXYCAMPTOTHECIN                     Irinotecan       1
# 2                           ABIRATERONE            Abiraterone acetate       1
# 3                           AFIMOXIFENE                      Tamoxifen       1
# 4                           CANDESARTAN          Candesartan cilexetil       1
# 5                        CLOFIBRIC ACID                     Clofibrate       1
# 6                            DABIGATRAN           Dabigatran etexilate       1
# 7                       DESGLYMIDODRINE                      Midodrine       1
# 8                         DESLORATADINE                     Loratidine       1
# 9                           ENALAPRILAT                      Enalapril       1
# 10                    ETHINYL ESTRADIOL                      Mestranol       1
# 11                      FENOFIBRIC ACID                    Fenofibrate       1
# 12                         FEXOFENADINE                    Terfenadine       1
# 13        FINGOLIMOD PHOSPHATE/FTY720-P                     Fingolimod       1
# 14                         FLUPROSTENOL                     Travoprost       1
# 15                         FOSINOPRILAT                     Fosinopril       1
# 16                          HALOPERIDOL          Haloperidol decanoate       1
# 17                     HYDROXYFLUTAMIDE                      Flutamide       1
# 18              LAMIVUDINE TRIPHOSPHATE                     Lamivudine       1
# 19                          LANINAMIVIR          Laninamivir octanoate       1
# 20             LOXOPROFEN TRANS ALCOHOL                     Loxoprofen       1
# 21          OSELTAMIVIR CARBOXYLIC ACID                    Oseltamivir       1
# 22                           OXYPURINOL                    Allopurinol       1
# 23                         PREDNISOLONE                     Prednisone       1
# 24                          QUINAPRILAT                      Quinapril       1
# 25                                R-406                   Fostamatinib       1
# 26                  ROMIDESPSIN_DITHIOL                     Romidepsin       1
# 27                          SPIRAPRILAT                      Spirapril       1
# 28               STAVUDINE TRIPHOSPHATE                      Stavudine       1
# 29                     SULINDAC SULFIDE                       Sulindac       1
# 30                         TESTOSTERONE        Testosterone propionate       1
# 31              ZIDOVUDINE TRIPHOSPHATE                     Zidovudine       1
# 32                        BETAMETHASONE  Betamethasone phosphoric acid       1
# 33                        TERIFLUNOMIDE                    Leflunomide       1
# 34                          IMIDAPRILAT                      Imidapril       1
# 35                            ESTRADIOL             Estradiol benzoate       1
# 36                          CYCLOGUANIL                  Chloroguanide       1
# 37                           MELAGATRAN                   Ximelagatran       1

# %%
prodrugs_2 = df_paper[['CMPD_PREF_NAME (Active metabolite).1', 'CMPD_PREF_NAME (Prodrug removed, not used in analysis since no potency data for active metabolite-drug target interaction)']].dropna()
prodrugs_2 = prodrugs_2.rename(columns={'CMPD_PREF_NAME (Active metabolite).1': 'active_metabolite_pref_name',
                          'CMPD_PREF_NAME (Prodrug removed, not used in analysis since no potency data for active metabolite-drug target interaction)':'prodrug_pref_name'})
prodrugs_2['column'] = 2
prodrugs_2
# Out:
#             active_metabolite_pref_name      prodrug_pref_name  column
# 0                 CARBOVIR TRIPHOSPHATE               Abacavir       2
# 1   5-AZA-2′-DEOXYCYTIDINE TRIPHOSPHATE            Azacitidine       2
# 2               DECITABINE TRIPHOSPHATE             Decitabine       2
# 3                           DIFLORASONE  Diflorasone diacetate       2
# 4                           MOEXIPRILAT              Moexipril       2
# 5                         PERINDOPRILAT            Perindopril       2
# 6                            RAMIPRILAT               Ramipril       2
# 7                      TAZAROTENIC ACID             Tazarotene       2
# 8                        TRANDOLAPRILAT           Trandolapril       2
# 9                          BENAZEPRILAT             Benazepril       2
# 10                     MEVINOLINIC ACID             Lovastatin       2
# 11                         TENIVASTATIN            Simvastatin       2
# 12                            GS-461203             Sofosbuvir       2
# 13                                DDCTP            Zalcitabine       2
# 14             OMEPRAZOLE SULFENIC ACID             Omeprazole       2
# 15                           ROXATIDINE     Roxatidine acetate       2
# 16                          CAREBASTINE               Ebastine       2
# 17                    4-OH-ENCLOMIPHENE           Enclomiphene       2

# %%
prodrugs = pd.concat([prodrugs_1, prodrugs_2])
prodrugs['prodrug_pref_name'] = prodrugs['prodrug_pref_name'].str.upper()
print("#produgs:", len(prodrugs))
prodrugs
# Out:
# #produgs: 56
#             active_metabolite_pref_name              prodrug_pref_name  column
# 0   2',3'-DIDEOXYADENOSINE TRIPHOSPHATE                     DIDANOSINE       1
# 1        7-ETHYL-10-HYDROXYCAMPTOTHECIN                     IRINOTECAN       1
# 2                           ABIRATERONE            ABIRATERONE ACETATE       1
# 3                           AFIMOXIFENE                      TAMOXIFEN       1
# 4                           CANDESARTAN          CANDESARTAN CILEXETIL       1
# 5                        CLOFIBRIC ACID                     CLOFIBRATE       1
# 6                            DABIGATRAN           DABIGATRAN ETEXILATE       1
# 7                       DESGLYMIDODRINE                      MIDODRINE       1
# 8                         DESLORATADINE                     LORATIDINE       1
# 9                           ENALAPRILAT                      ENALAPRIL       1
# 10                    ETHINYL ESTRADIOL                      MESTRANOL       1
# 11                      FENOFIBRIC ACID                    FENOFIBRATE       1
# 12                         FEXOFENADINE                    TERFENADINE       1
# 13        FINGOLIMOD PHOSPHATE/FTY720-P                     FINGOLIMOD       1
# 14                         FLUPROSTENOL                     TRAVOPROST       1
# 15                         FOSINOPRILAT                     FOSINOPRIL       1
# 16                          HALOPERIDOL          HALOPERIDOL DECANOATE       1
# 17                     HYDROXYFLUTAMIDE                      FLUTAMIDE       1
# 18              LAMIVUDINE TRIPHOSPHATE                     LAMIVUDINE       1
# 19                          LANINAMIVIR          LANINAMIVIR OCTANOATE       1
# 20             LOXOPROFEN TRANS ALCOHOL                     LOXOPROFEN       1
# 21          OSELTAMIVIR CARBOXYLIC ACID                    OSELTAMIVIR       1
# 22                           OXYPURINOL                    ALLOPURINOL       1
# 23                         PREDNISOLONE                     PREDNISONE       1
# 24                          QUINAPRILAT                      QUINAPRIL       1
# 25                                R-406                   FOSTAMATINIB       1
# 26                  ROMIDESPSIN_DITHIOL                     ROMIDEPSIN       1
# 27                          SPIRAPRILAT                      SPIRAPRIL       1
# 28               STAVUDINE TRIPHOSPHATE                      STAVUDINE       1
# 29                     SULINDAC SULFIDE                       SULINDAC       1
# 30                         TESTOSTERONE        TESTOSTERONE PROPIONATE       1
# 31              ZIDOVUDINE TRIPHOSPHATE                     ZIDOVUDINE       1
# 32                        BETAMETHASONE  BETAMETHASONE PHOSPHORIC ACID       1
# 33                        TERIFLUNOMIDE                    LEFLUNOMIDE       1
# 34                          IMIDAPRILAT                      IMIDAPRIL       1
# 35                            ESTRADIOL             ESTRADIOL BENZOATE       1
# 36                          CYCLOGUANIL                  CHLOROGUANIDE       1
# 37                           MELAGATRAN                   XIMELAGATRAN       1
# 0                 CARBOVIR TRIPHOSPHATE                       ABACAVIR       2
# 1   5-AZA-2′-DEOXYCYTIDINE TRIPHOSPHATE                    AZACITIDINE       2
# 2               DECITABINE TRIPHOSPHATE                     DECITABINE       2
# 3                           DIFLORASONE          DIFLORASONE DIACETATE       2
# 4                           MOEXIPRILAT                      MOEXIPRIL       2
# 5                         PERINDOPRILAT                    PERINDOPRIL       2
# 6                            RAMIPRILAT                       RAMIPRIL       2
# 7                      TAZAROTENIC ACID                     TAZAROTENE       2
# 8                        TRANDOLAPRILAT                   TRANDOLAPRIL       2
# 9                          BENAZEPRILAT                     BENAZEPRIL       2
# 10                     MEVINOLINIC ACID                     LOVASTATIN       2
# 11                         TENIVASTATIN                    SIMVASTATIN       2
# 12                            GS-461203                     SOFOSBUVIR       2
# 13                                DDCTP                    ZALCITABINE       2
# 14             OMEPRAZOLE SULFENIC ACID                     OMEPRAZOLE       2
# 15                           ROXATIDINE             ROXATIDINE ACETATE       2
# 16                          CAREBASTINE                       EBASTINE       2
# 17                    4-OH-ENCLOMIPHENE                   ENCLOMIPHENE       2

# %% [markdown]
# ## Compound information from ChEMBL26

# %%
sql = """
SELECT DISTINCT md.molregno as salt_molregno, md.pref_name as salt_pref_name, md.chembl_id as salt_chembl_id,
    md2.molregno as parent_molregno, md2.pref_name as parent_pref_name, md2.chembl_id as parent_chembl_id
FROM molecule_dictionary md
JOIN molecule_hierarchy mh 
    ON md.molregno = mh.molregno
JOIN molecule_dictionary md2 
    ON mh.parent_molregno = md2.molregno                           --parent_molregno
WHERE md.pref_name is not null
"""

df_mols = pd.read_sql_query(sql, con=engine_ch)
df_mols
# Out:
#        salt_molregno    salt_pref_name salt_chembl_id  parent_molregno  \
# 0                250         SB-203580       CHEMBL10              250
# 1              12356     LEVCROMAKALIM      CHEMBL100            12356
# 2             111185        CETIRIZINE     CHEMBL1000           111185
# 3             164444              AN-9   CHEMBL100014           164444
# 4             165474       PENTAZOCINE   CHEMBL100116           165474
# ...              ...               ...            ...              ...
# 45523         164806       IMIDAPRILAT    CHEMBL99701           164806
# 45524         161939          PAULLONE    CHEMBL99779           161939
# 45525         110803        LORATADINE      CHEMBL998           110803
# 45526         160881  8-AMINOQUINOLINE    CHEMBL99932           160881
# 45527         164035   LEVOMILNACIPRAN    CHEMBL99946           164035
#
#        parent_pref_name parent_chembl_id
# 0             SB-203580         CHEMBL10
# 1         LEVCROMAKALIM        CHEMBL100
# 2            CETIRIZINE       CHEMBL1000
# 3                  AN-9     CHEMBL100014
# 4           PENTAZOCINE     CHEMBL100116
# ...                 ...              ...
# 45523       IMIDAPRILAT      CHEMBL99701
# 45524          PAULLONE      CHEMBL99779
# 45525        LORATADINE        CHEMBL998
# 45526  8-AMINOQUINOLINE      CHEMBL99932
# 45527   LEVOMILNACIPRAN      CHEMBL99946
#
# [45528 rows x 6 columns]

# %% [markdown]
# ## Combine prodrug information with the ChEMBL information

# %%
df_combined = prodrugs.merge(df_mols, left_on='prodrug_pref_name', right_on='salt_pref_name', how="left")
print("Salts and parents are identical:", df_combined['salt_molregno'].equals(df_combined['parent_molregno']))
df_combined = df_combined.drop(['salt_molregno', 'salt_pref_name', 'salt_chembl_id'], axis=1)
df_combined = df_combined.rename(columns={'parent_molregno': 'prodrug_parent_molregno', 
                                            'parent_pref_name': 'prodrug_parent_pref_name',
                                            'parent_chembl_id': 'prodrug_parent_chembl_id'})
df_combined
# Out:
# Salts and parents are identical: True
#             active_metabolite_pref_name              prodrug_pref_name  \
# 0   2',3'-DIDEOXYADENOSINE TRIPHOSPHATE                     DIDANOSINE
# 1        7-ETHYL-10-HYDROXYCAMPTOTHECIN                     IRINOTECAN
# 2                           ABIRATERONE            ABIRATERONE ACETATE
# 3                           AFIMOXIFENE                      TAMOXIFEN
# 4                           CANDESARTAN          CANDESARTAN CILEXETIL
# 5                        CLOFIBRIC ACID                     CLOFIBRATE
# 6                            DABIGATRAN           DABIGATRAN ETEXILATE
# 7                       DESGLYMIDODRINE                      MIDODRINE
# 8                         DESLORATADINE                     LORATIDINE
# 9                           ENALAPRILAT                      ENALAPRIL
# 10                    ETHINYL ESTRADIOL                      MESTRANOL
# 11                      FENOFIBRIC ACID                    FENOFIBRATE
# 12                         FEXOFENADINE                    TERFENADINE
# 13        FINGOLIMOD PHOSPHATE/FTY720-P                     FINGOLIMOD
# 14                         FLUPROSTENOL                     TRAVOPROST
# 15                         FOSINOPRILAT                     FOSINOPRIL
# 16                          HALOPERIDOL          HALOPERIDOL DECANOATE
# 17                     HYDROXYFLUTAMIDE                      FLUTAMIDE
# 18              LAMIVUDINE TRIPHOSPHATE                     LAMIVUDINE
# 19                          LANINAMIVIR          LANINAMIVIR OCTANOATE
# 20             LOXOPROFEN TRANS ALCOHOL                     LOXOPROFEN
# 21          OSELTAMIVIR CARBOXYLIC ACID                    OSELTAMIVIR
# 22                           OXYPURINOL                    ALLOPURINOL
# 23                         PREDNISOLONE                     PREDNISONE
# 24                          QUINAPRILAT                      QUINAPRIL
# 25                                R-406                   FOSTAMATINIB
# 26                  ROMIDESPSIN_DITHIOL                     ROMIDEPSIN
# 27                          SPIRAPRILAT                      SPIRAPRIL
# 28               STAVUDINE TRIPHOSPHATE                      STAVUDINE
# 29                     SULINDAC SULFIDE                       SULINDAC
# 30                         TESTOSTERONE        TESTOSTERONE PROPIONATE
# 31              ZIDOVUDINE TRIPHOSPHATE                     ZIDOVUDINE
# 32                        BETAMETHASONE  BETAMETHASONE PHOSPHORIC ACID
# 33                        TERIFLUNOMIDE                    LEFLUNOMIDE
# 34                          IMIDAPRILAT                      IMIDAPRIL
# 35                            ESTRADIOL             ESTRADIOL BENZOATE
# 36                          CYCLOGUANIL                  CHLOROGUANIDE
# 37                           MELAGATRAN                   XIMELAGATRAN
# 38                CARBOVIR TRIPHOSPHATE                       ABACAVIR
# 39  5-AZA-2′-DEOXYCYTIDINE TRIPHOSPHATE                    AZACITIDINE
# 40              DECITABINE TRIPHOSPHATE                     DECITABINE
# 41                          DIFLORASONE          DIFLORASONE DIACETATE
# 42                          MOEXIPRILAT                      MOEXIPRIL
# 43                        PERINDOPRILAT                    PERINDOPRIL
# 44                           RAMIPRILAT                       RAMIPRIL
# 45                     TAZAROTENIC ACID                     TAZAROTENE
# 46                       TRANDOLAPRILAT                   TRANDOLAPRIL
# 47                         BENAZEPRILAT                     BENAZEPRIL
# 48                     MEVINOLINIC ACID                     LOVASTATIN
# 49                         TENIVASTATIN                    SIMVASTATIN
# 50                            GS-461203                     SOFOSBUVIR
# 51                                DDCTP                    ZALCITABINE
# 52             OMEPRAZOLE SULFENIC ACID                     OMEPRAZOLE
# 53                           ROXATIDINE             ROXATIDINE ACETATE
# 54                          CAREBASTINE                       EBASTINE
# 55                    4-OH-ENCLOMIPHENE                   ENCLOMIPHENE
#
#     column  prodrug_parent_molregno       prodrug_parent_pref_name  \
# 0        1                 390877.0                     DIDANOSINE
# 1        1                   5985.0                     IRINOTECAN
# 2        1                 438435.0            ABIRATERONE ACETATE
# 3        1                   6968.0                      TAMOXIFEN
# 4        1                 116349.0          CANDESARTAN CILEXETIL
# 5        1                  16415.0                     CLOFIBRATE
# 6        1                 561520.0           DABIGATRAN ETEXILATE
# 7        1                 675163.0                      MIDODRINE
# 8        1                      NaN                            NaN
# 9        1                  16847.0                      ENALAPRIL
# 10       1                 675102.0                      MESTRANOL
# 11       1                  28331.0                    FENOFIBRATE
# 12       1                  19569.0                    TERFENADINE
# 13       1                 144940.0                     FINGOLIMOD
# 14       1                 674750.0                     TRAVOPROST
# 15       1                1592409.0                     FOSINOPRIL
# 16       1                 674937.0          HALOPERIDOL DECANOATE
# 17       1                  52087.0                      FLUTAMIDE
# 18       1                  33986.0                     LAMIVUDINE
# 19       1                 479445.0          LANINAMIVIR OCTANOATE
# 20       1                  22873.0                     LOXOPROFEN
# 21       1                 228121.0                    OSELTAMIVIR
# 22       1                 395607.0                    ALLOPURINOL
# 23       1                  27229.0                     PREDNISONE
# 24       1                 454141.0                      QUINAPRIL
# 25       1                1376100.0                   FOSTAMATINIB
# 26       1                 246935.0                     ROMIDEPSIN
# 27       1                   1967.0                      SPIRAPRIL
# 28       1                 107119.0                      STAVUDINE
# 29       1                  16510.0                       SULINDAC
# 30       1                 190629.0        TESTOSTERONE PROPIONATE
# 31       1                  27307.0                     ZIDOVUDINE
# 32       1                 675158.0  BETAMETHASONE PHOSPHORIC ACID
# 33       1                  93895.0                    LEFLUNOMIDE
# 34       1                 164680.0                      IMIDAPRIL
# 35       1                  39821.0             ESTRADIOL BENZOATE
# 36       1                 320522.0                  CHLOROGUANIDE
# 37       1                 478003.0                   XIMELAGATRAN
# 38       2                 321707.0                       ABACAVIR
# 39       2                 418401.0                    AZACITIDINE
# 40       2                 675080.0                     DECITABINE
# 41       2                 674496.0          DIFLORASONE DIACETATE
# 42       2                 188707.0                      MOEXIPRIL
# 43       2                 453579.0                    PERINDOPRIL
# 44       2                 189203.0                       RAMIPRIL
# 45       2                 495572.0                     TAZAROTENE
# 46       2                 421317.0                   TRANDOLAPRIL
# 47       2                  61706.0                     BENAZEPRIL
# 48       2                   9495.0                     LOVASTATIN
# 49       2                 138562.0                    SIMVASTATIN
# 50       2                 708075.0                     SOFOSBUVIR
# 51       2                  65494.0                    ZALCITABINE
# 52       2                 419601.0                     OMEPRAZOLE
# 53       2                  71339.0             ROXATIDINE ACETATE
# 54       2                 111060.0                       EBASTINE
# 55       2                  92984.0                   ENCLOMIPHENE
#
#    prodrug_parent_chembl_id
# 0                CHEMBL1460
# 1                 CHEMBL481
# 2              CHEMBL271227
# 3                  CHEMBL83
# 4                CHEMBL1014
# 5                 CHEMBL565
# 6              CHEMBL539697
# 7             CHEMBL1201212
# 8                       NaN
# 9                 CHEMBL578
# 10            CHEMBL1201151
# 11                CHEMBL672
# 12              CHEMBL17157
# 13             CHEMBL314854
# 14            CHEMBL1200799
# 15            CHEMBL3039598
# 16            CHEMBL1200986
# 17                CHEMBL806
# 18                CHEMBL141
# 19             CHEMBL467058
# 20              CHEMBL19299
# 21               CHEMBL1229
# 22               CHEMBL1467
# 23                CHEMBL635
# 24               CHEMBL1592
# 25            CHEMBL2103830
# 26             CHEMBL343448
# 27                CHEMBL431
# 28                CHEMBL991
# 29              CHEMBL15770
# 30               CHEMBL1170
# 31                CHEMBL129
# 32            CHEMBL1201207
# 33                CHEMBL960
# 34             CHEMBL317094
# 35             CHEMBL282575
# 36               CHEMBL1377
# 37             CHEMBL522038
# 38               CHEMBL1380
# 39               CHEMBL1489
# 40            CHEMBL1201129
# 41            CHEMBL1200545
# 42               CHEMBL1165
# 43               CHEMBL1581
# 44               CHEMBL1168
# 45               CHEMBL1657
# 46               CHEMBL1519
# 47                CHEMBL838
# 48                CHEMBL503
# 49               CHEMBL1064
# 50            CHEMBL1259059
# 51                CHEMBL853
# 52               CHEMBL1503
# 53              CHEMBL46102
# 54             CHEMBL305660
# 55                CHEMBL954

# %%
df_combined = df_combined.merge(df_mols, left_on='active_metabolite_pref_name', right_on='salt_pref_name', how="left")

print("Salts and parents are identical:", df_combined['salt_molregno'].equals(df_combined['parent_molregno']))
print("Salt and parent info are not identical: ")
df_combined[(~df_combined['salt_molregno'].isnull()) & (df_combined['salt_molregno'] != df_combined['parent_molregno'])]
# Out:
# Salts and parents are identical: False
# Salt and parent info are not identical:
#    active_metabolite_pref_name prodrug_pref_name  column  \
# 11                 ENALAPRILAT         ENALAPRIL       1
#
#     prodrug_parent_molregno prodrug_parent_pref_name prodrug_parent_chembl_id  \
# 11                  16847.0                ENALAPRIL                CHEMBL578
#
#     salt_molregno salt_pref_name salt_chembl_id  parent_molregno  \
# 11      2197277.0    ENALAPRILAT  CHEMBL3989406          16759.0
#
#    parent_pref_name parent_chembl_id
# 11      ENALAPRILAT        CHEMBL577

# %%
df_combined = df_combined.drop(['salt_molregno', 'salt_pref_name', 'salt_chembl_id'], axis=1)
df_combined = df_combined.rename(columns={'parent_molregno': 'active_metabolite_parent_molregno', 
                                            'parent_pref_name': 'active_metabolite_parent_pref_name',
                                            'parent_chembl_id': 'active_metabolite_parent_chembl_id'})
df_combined = df_combined.drop_duplicates()
print("Info about prodrugs:", len(df_combined), "(for", len(prodrugs), "prodrugs)")
df_combined
# Out:
# Info about prodrugs: 58 (for 56 prodrugs)
#             active_metabolite_pref_name              prodrug_pref_name  \
# 0   2',3'-DIDEOXYADENOSINE TRIPHOSPHATE                     DIDANOSINE
# 1        7-ETHYL-10-HYDROXYCAMPTOTHECIN                     IRINOTECAN
# 2                           ABIRATERONE            ABIRATERONE ACETATE
# 3                           AFIMOXIFENE                      TAMOXIFEN
# 4                           AFIMOXIFENE                      TAMOXIFEN
# 5                           AFIMOXIFENE                      TAMOXIFEN
# 6                           CANDESARTAN          CANDESARTAN CILEXETIL
# 7                        CLOFIBRIC ACID                     CLOFIBRATE
# 8                            DABIGATRAN           DABIGATRAN ETEXILATE
# 9                       DESGLYMIDODRINE                      MIDODRINE
# 10                        DESLORATADINE                     LORATIDINE
# 11                          ENALAPRILAT                      ENALAPRIL
# 13                    ETHINYL ESTRADIOL                      MESTRANOL
# 14                      FENOFIBRIC ACID                    FENOFIBRATE
# 15                         FEXOFENADINE                    TERFENADINE
# 16        FINGOLIMOD PHOSPHATE/FTY720-P                     FINGOLIMOD
# 17                         FLUPROSTENOL                     TRAVOPROST
# 18                         FOSINOPRILAT                     FOSINOPRIL
# 19                          HALOPERIDOL          HALOPERIDOL DECANOATE
# 20                     HYDROXYFLUTAMIDE                      FLUTAMIDE
# 21              LAMIVUDINE TRIPHOSPHATE                     LAMIVUDINE
# 22                          LANINAMIVIR          LANINAMIVIR OCTANOATE
# 23             LOXOPROFEN TRANS ALCOHOL                     LOXOPROFEN
# 24          OSELTAMIVIR CARBOXYLIC ACID                    OSELTAMIVIR
# 25                           OXYPURINOL                    ALLOPURINOL
# 26                         PREDNISOLONE                     PREDNISONE
# 27                          QUINAPRILAT                      QUINAPRIL
# 28                                R-406                   FOSTAMATINIB
# 29                  ROMIDESPSIN_DITHIOL                     ROMIDEPSIN
# 30                          SPIRAPRILAT                      SPIRAPRIL
# 31               STAVUDINE TRIPHOSPHATE                      STAVUDINE
# 32                     SULINDAC SULFIDE                       SULINDAC
# 33                         TESTOSTERONE        TESTOSTERONE PROPIONATE
# 34              ZIDOVUDINE TRIPHOSPHATE                     ZIDOVUDINE
# 35                        BETAMETHASONE  BETAMETHASONE PHOSPHORIC ACID
# 36                        TERIFLUNOMIDE                    LEFLUNOMIDE
# 37                          IMIDAPRILAT                      IMIDAPRIL
# 38                            ESTRADIOL             ESTRADIOL BENZOATE
# 39                          CYCLOGUANIL                  CHLOROGUANIDE
# 40                           MELAGATRAN                   XIMELAGATRAN
# 41                CARBOVIR TRIPHOSPHATE                       ABACAVIR
# 42  5-AZA-2′-DEOXYCYTIDINE TRIPHOSPHATE                    AZACITIDINE
# 43              DECITABINE TRIPHOSPHATE                     DECITABINE
# 44                          DIFLORASONE          DIFLORASONE DIACETATE
# 45                          MOEXIPRILAT                      MOEXIPRIL
# 46                        PERINDOPRILAT                    PERINDOPRIL
# 47                           RAMIPRILAT                       RAMIPRIL
# 48                     TAZAROTENIC ACID                     TAZAROTENE
# 49                       TRANDOLAPRILAT                   TRANDOLAPRIL
# 50                         BENAZEPRILAT                     BENAZEPRIL
# 51                     MEVINOLINIC ACID                     LOVASTATIN
# 52                         TENIVASTATIN                    SIMVASTATIN
# 53                            GS-461203                     SOFOSBUVIR
# 54                                DDCTP                    ZALCITABINE
# 55             OMEPRAZOLE SULFENIC ACID                     OMEPRAZOLE
# 56                           ROXATIDINE             ROXATIDINE ACETATE
# 57                          CAREBASTINE                       EBASTINE
# 58                    4-OH-ENCLOMIPHENE                   ENCLOMIPHENE
#
#     column  prodrug_parent_molregno       prodrug_parent_pref_name  \
# 0        1                 390877.0                     DIDANOSINE
# 1        1                   5985.0                     IRINOTECAN
# 2        1                 438435.0            ABIRATERONE ACETATE
# 3        1                   6968.0                      TAMOXIFEN
# 4        1                   6968.0                      TAMOXIFEN
# 5        1                   6968.0                      TAMOXIFEN
# 6        1                 116349.0          CANDESARTAN CILEXETIL
# 7        1                  16415.0                     CLOFIBRATE
# 8        1                 561520.0           DABIGATRAN ETEXILATE
# 9        1                 675163.0                      MIDODRINE
# 10       1                      NaN                            NaN
# 11       1                  16847.0                      ENALAPRIL
# 13       1                 675102.0                      MESTRANOL
# 14       1                  28331.0                    FENOFIBRATE
# 15       1                  19569.0                    TERFENADINE
# 16       1                 144940.0                     FINGOLIMOD
# 17       1                 674750.0                     TRAVOPROST
# 18       1                1592409.0                     FOSINOPRIL
# 19       1                 674937.0          HALOPERIDOL DECANOATE
# 20       1                  52087.0                      FLUTAMIDE
# 21       1                  33986.0                     LAMIVUDINE
# 22       1                 479445.0          LANINAMIVIR OCTANOATE
# 23       1                  22873.0                     LOXOPROFEN
# 24       1                 228121.0                    OSELTAMIVIR
# 25       1                 395607.0                    ALLOPURINOL
# 26       1                  27229.0                     PREDNISONE
# 27       1                 454141.0                      QUINAPRIL
# 28       1                1376100.0                   FOSTAMATINIB
# 29       1                 246935.0                     ROMIDEPSIN
# 30       1                   1967.0                      SPIRAPRIL
# 31       1                 107119.0                      STAVUDINE
# 32       1                  16510.0                       SULINDAC
# 33       1                 190629.0        TESTOSTERONE PROPIONATE
# 34       1                  27307.0                     ZIDOVUDINE
# 35       1                 675158.0  BETAMETHASONE PHOSPHORIC ACID
# 36       1                  93895.0                    LEFLUNOMIDE
# 37       1                 164680.0                      IMIDAPRIL
# 38       1                  39821.0             ESTRADIOL BENZOATE
# 39       1                 320522.0                  CHLOROGUANIDE
# 40       1                 478003.0                   XIMELAGATRAN
# 41       2                 321707.0                       ABACAVIR
# 42       2                 418401.0                    AZACITIDINE
# 43       2                 675080.0                     DECITABINE
# 44       2                 674496.0          DIFLORASONE DIACETATE
# 45       2                 188707.0                      MOEXIPRIL
# 46       2                 453579.0                    PERINDOPRIL
# 47       2                 189203.0                       RAMIPRIL
# 48       2                 495572.0                     TAZAROTENE
# 49       2                 421317.0                   TRANDOLAPRIL
# 50       2                  61706.0                     BENAZEPRIL
# 51       2                   9495.0                     LOVASTATIN
# 52       2                 138562.0                    SIMVASTATIN
# 53       2                 708075.0                     SOFOSBUVIR
# 54       2                  65494.0                    ZALCITABINE
# 55       2                 419601.0                     OMEPRAZOLE
# 56       2                  71339.0             ROXATIDINE ACETATE
# 57       2                 111060.0                       EBASTINE
# 58       2                  92984.0                   ENCLOMIPHENE
#
#    prodrug_parent_chembl_id  active_metabolite_parent_molregno  \
# 0                CHEMBL1460                           323638.0
# 1                 CHEMBL481                            61315.0
# 2              CHEMBL271227                           422175.0
# 3                  CHEMBL83                             6341.0
# 4                  CHEMBL83                          1408997.0
# 5                  CHEMBL83                             6402.0
# 6                CHEMBL1014                           116848.0
# 7                 CHEMBL565                            29390.0
# 8              CHEMBL539697                            75302.0
# 9             CHEMBL1201212                           140006.0
# 10                      NaN                           191342.0
# 11                CHEMBL578                            16759.0
# 13            CHEMBL1201151                            31241.0
# 14                CHEMBL672                           100310.0
# 15              CHEMBL17157                            81683.0
# 16             CHEMBL314854                                NaN
# 17            CHEMBL1200799                           675330.0
# 18            CHEMBL3039598                            16962.0
# 19            CHEMBL1200986                             3859.0
# 20                CHEMBL806                             6787.0
# 21                CHEMBL141                           228191.0
# 22             CHEMBL467058                           479511.0
# 23              CHEMBL19299                                NaN
# 24               CHEMBL1229                            28675.0
# 25               CHEMBL1467                            65935.0
# 26                CHEMBL635                            27370.0
# 27               CHEMBL1592                           561889.0
# 28            CHEMBL2103830                           460144.0
# 29             CHEMBL343448                                NaN
# 30                CHEMBL431                            16952.0
# 31                CHEMBL991                           499980.0
# 32              CHEMBL15770                            21650.0
# 33               CHEMBL1170                           364520.0
# 34                CHEMBL129                           323000.0
# 35            CHEMBL1201207                            27152.0
# 36                CHEMBL960                            96107.0
# 37             CHEMBL317094                           164806.0
# 38             CHEMBL282575                            27626.0
# 39               CHEMBL1377                            39570.0
# 40             CHEMBL522038                             2451.0
# 41               CHEMBL1380                                NaN
# 42               CHEMBL1489                                NaN
# 43            CHEMBL1201129                                NaN
# 44            CHEMBL1200545                                NaN
# 45               CHEMBL1165                           675356.0
# 46               CHEMBL1581                           675319.0
# 47               CHEMBL1168                           675316.0
# 48               CHEMBL1657                                NaN
# 49               CHEMBL1519                           675338.0
# 50                CHEMBL838                           666469.0
# 51                CHEMBL503                           675324.0
# 52               CHEMBL1064                           675342.0
# 53            CHEMBL1259059                                NaN
# 54                CHEMBL853                                NaN
# 55               CHEMBL1503                                NaN
# 56              CHEMBL46102                                NaN
# 57             CHEMBL305660                           111134.0
# 58                CHEMBL954                                NaN
#
#      active_metabolite_parent_pref_name active_metabolite_parent_chembl_id
# 0   2',3'-DIDEOXYADENOSINE TRIPHOSPHATE                         CHEMBL1383
# 1        7-ETHYL-10-HYDROXYCAMPTOTHECIN                          CHEMBL837
# 2                           ABIRATERONE                       CHEMBL254328
# 3                           AFIMOXIFENE                        CHEMBL10041
# 4                           AFIMOXIFENE                      CHEMBL2137046
# 5                           AFIMOXIFENE                          CHEMBL489
# 6                           CANDESARTAN                         CHEMBL1016
# 7                        CLOFIBRIC ACID                          CHEMBL683
# 8                            DABIGATRAN                        CHEMBL48361
# 9                       DESGLYMIDODRINE                         CHEMBL1076
# 10                        DESLORATADINE                         CHEMBL1172
# 11                          ENALAPRILAT                          CHEMBL577
# 13                    ETHINYL ESTRADIOL                          CHEMBL691
# 14                      FENOFIBRIC ACID                          CHEMBL981
# 15                         FEXOFENADINE                          CHEMBL914
# 16                                  NaN                                NaN
# 17                         FLUPROSTENOL                      CHEMBL1201379
# 18                         FOSINOPRILAT                          CHEMBL581
# 19                          HALOPERIDOL                           CHEMBL54
# 20                     HYDROXYFLUTAMIDE                          CHEMBL491
# 21              LAMIVUDINE TRIPHOSPHATE                         CHEMBL1230
# 22                          LANINAMIVIR                       CHEMBL466246
# 23                                  NaN                                NaN
# 24          OSELTAMIVIR CARBOXYLIC ACID                          CHEMBL674
# 25                           OXYPURINOL                          CHEMBL859
# 26                         PREDNISOLONE                          CHEMBL131
# 27                          QUINAPRILAT                         CHEMBL1733
# 28                                R-406                       CHEMBL475251
# 29                                  NaN                                NaN
# 30                          SPIRAPRILAT                          CHEMBL579
# 31               STAVUDINE TRIPHOSPHATE                       CHEMBL485652
# 32                     SULINDAC SULFIDE                        CHEMBL18797
# 33                         TESTOSTERONE                       CHEMBL386630
# 34              ZIDOVUDINE TRIPHOSPHATE                       CHEMBL193952
# 35                        BETAMETHASONE                          CHEMBL632
# 36                        TERIFLUNOMIDE                          CHEMBL973
# 37                          IMIDAPRILAT                        CHEMBL99701
# 38                            ESTRADIOL                          CHEMBL135
# 39                          CYCLOGUANIL                          CHEMBL747
# 40                           MELAGATRAN                       CHEMBL266349
# 41                                  NaN                                NaN
# 42                                  NaN                                NaN
# 43                                  NaN                                NaN
# 44                                  NaN                                NaN
# 45                          MOEXIPRILAT                      CHEMBL1201405
# 46                        PERINDOPRILAT                      CHEMBL1201368
# 47                           RAMIPRILAT                      CHEMBL1201365
# 48                                  NaN                                NaN
# 49                       TRANDOLAPRILAT                      CHEMBL1201387
# 50                         BENAZEPRILAT                      CHEMBL1192519
# 51                     MEVINOLINIC ACID                      CHEMBL1201373
# 52                         TENIVASTATIN                      CHEMBL1201391
# 53                                  NaN                                NaN
# 54                                  NaN                                NaN
# 55                                  NaN                                NaN
# 56                                  NaN                                NaN
# 57                          CAREBASTINE                        CHEMBL67654
# 58                                  NaN                                NaN

# %% [markdown]
# ## Save information to csv

# %%
df_combined.to_csv(path_results+'prodrugs.csv', index=False)
